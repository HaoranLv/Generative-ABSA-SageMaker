# %%
import numpy as np
# from eval_utils import *

# %%
# !pip install editdistance
# Out:
# Collecting editdistance
#   Downloading editdistance-0.6.0-cp38-cp38-macosx_10_9_x86_64.whl (21 kB)
# Installing collected packages: editdistance
# Successfully installed editdistance-0.6.0

# %%
lab=np.load('labels.npy',allow_pickle=True)
pre=np.load('predictions_nofix.npy',allow_pickle=True)

# %%
lab[0][0]
# Out:
# ('网速', '正')

# %%
list(pre[1][0])
pred=[]
for i in pre:
    pred.append([])
    for j in i:
        pred[-1].append((list(i[0])[0],list(i[0])[1]))

# %%
pred=np.array(pred)

# %%
pred
# Out:
# [[('网速', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '负')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('儿童玩具', '其他')],
#  [('网速', '正')],
#  [('文化主题', '正')],
#  [('', '')],
#  [('儿童餐饮', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童餐饮', '其他')],
#  [('网速', '正')],
#  [('', '')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('键盘', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('鼠标', '正')],
#  [('耳机', '正')],
#  [('笼统电竞体验', '负')],
#  [('', '')],
#  [('儿童活动', '其他')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('文化主题', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('笼统游戏体验', '正')],
#  [('推荐亲子入住', '负')],
#  [('鼠标', '正')],
#  [('儿童餐饮', '负')],
#  [('鼠标', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童玩具', '其他')],
#  [('电竞椅', '正')],
#  [('推荐亲子入住', '负')],
#  [('网速', '正')],
#  [('', '')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('儿童日用品', '其他')],
#  [('显示器', '负')],
#  [('孩子体验感受', '正')],
#  [('自然景观', '正')],
#  [('电竞椅', '正')],
#  [('网速', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('耳机', '正')],
#  [('儿童娱乐区', '负')],
#  [('孩子体验感受', '正')],
#  [('显卡', '正')],
#  [('', '')],
#  [('面积', '正')],
#  [('', '')],
#  [('网速', '正')],
#  [('', '')],
#  [('面积', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('电竞椅', '正')],
#  [('', '')],
#  [('自然景观', '正')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('', '')],
#  [('餐食', '负')],
#  [('孩子体验感受', '正')],
#  [('儿童玩具', '其他')],
#  [('推荐亲子入住', '负')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '其他')],
#  [('笼统游戏体验', '正')],
#  [('网速', '正')],
#  [('', '')],
#  [('味道', '正')],
#  [('', '')],
#  [('鼠标', '正')],
#  [('耳机', '负')],
#  [('', '')],
#  [('面积', '正')],
#  [('推荐亲子入住', '正')],
#  [('孩子体验感受', '正')],
#  [('文化主题', '其他')],
#  [('儿童娱乐区', '其他')],
#  [('鼠标', '正')],
#  [('', '')],
#  [('电竞椅', '其他')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '其他')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('键盘', '负')],
#  [('', '')],
#  [('电竞椅', '正')],
#  [('电竞椅', '正')],
#  [('自然景观', '正')],
#  [('孩子体验感受', '正')],
#  [('具体游戏体验', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('文化主题', '其他')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('电竞椅', '其他')],
#  [('儿童娱乐区', '其他')],
#  [('', '')],
#  [('儿童娱乐区', '负')],
#  [('鼠标', '负')],
#  [('', '')],
#  [('餐食', '正')],
#  [('', '')],
#  [('', '')],
#  [('网速', '正')],
#  [('推荐亲子入住', '负')],
#  [('网速', '正')],
#  [('推荐亲子入住', '负')],
#  [('孩子体验感受', '正')],
#  [('推荐电竞入住', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('自然景观', '正')],
#  [('儿童玩具', '负')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '负')],
#  [('自然景观', '其他')],
#  [('儿童餐饮', '负')],
#  [('餐食', '正')],
#  [('', '')],
#  [('鼠标', '正')],
#  [('键盘', '负')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('儿童餐饮', '其他')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('面积', '正')],
#  [('耳机', '负')],
#  [('儿童娱乐区', '其他')],
#  [('面积', '负')],
#  [('', '')],
#  [('', '')],
#  [('儿童日用品', '正')],
#  [('显卡', '正')],
#  [('', '')],
#  [('推荐亲子入住', '负')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '其他')],
#  [('儿童日用品', '其他')],
#  [('儿童日用品', '其他')],
#  [('', '')],
#  [('儿童玩具', '其他')],
#  [('', '')],
#  [('', '')],
#  [('味道', '正')],
#  [('', '')],
#  [('', '')],
#  [('推荐电竞入住', '正')],
#  [('儿童娱乐区', '其他')],
#  [('', '')],
#  [('自然景观', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童玩具', '其他')],
#  [('儿童活动', '正')],
#  [('', '')],
#  [('儿童活动', '正')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('儿童娱乐区', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('', '')],
#  [('笼统游戏体验', '正')],
#  [('网速', '负')],
#  [('', '')],
#  [('笼统电竞体验', '正')],
#  [('', '')],
#  [('儿童娱乐区', '正')],
#  [('键盘', '负')],
#  [('键盘', '负')],
#  [('显卡', '正')],
#  [('', '')],
#  [('', '')],
#  [('网速', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('自然景观', '正')],
#  [('', '')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('内存', '正')],
#  [('', '')],
#  [('电竞椅', '正')],
#  [('具体游戏体验', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('周边', '正')],
#  [('儿童餐饮', '负')],
#  [('儿童娱乐区', '其他')],
#  [('味道', '正')],
#  [('文化主题', '负')],
#  [('耳机', '正')],
#  [('', '')],
#  [('儿童玩具', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '其他')],
#  [('键盘', '负')],
#  [('显卡', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '其他')],
#  [('周边', '正')],
#  [('儿童娱乐区', '其他')],
#  [('', '')],
#  [('儿童餐饮', '其他')],
#  [('', '')],
#  [('儿童餐饮', '其他')],
#  [('', '')],
#  [('儿童玩具', '其他')],
#  [('电竞椅', '正')],
#  [('网速', '正')],
#  [('推荐亲子入住', '负')],
#  [('网速', '正')],
#  [('', '')],
#  [('儿童活动', '正')],
#  [('', '')],
#  [('推荐电竞入住', '正')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('内存', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童礼品', '其他')],
#  [('', '')],
#  [('', '')],
#  [('显示器', '其他')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('', '')],
#  [('味道', '负')],
#  [('', '')],
#  [('笼统游戏体验', '正')],
#  [('儿童娱乐区', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('耳机', '正')],
#  [('', '')],
#  [('', '')],
#  [('餐食', '正')],
#  [('儿童娱乐区', '其他')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('网速', '正')],
#  [('孩子体验感受', '正')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('鼠标', '正')],
#  [('孩子体验感受', '正')],
#  [('文化主题', '正')],
#  [('电竞椅', '正')],
#  [('网速', '负')],
#  [('文化主题', '正')],
#  [('', '')],
#  [('网速', '负')],
#  [('键盘', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童日用品', '其他')],
#  [('', '')],
#  [('', '')],
#  [('鼠标', '其他')],
#  [('鼠标', '负')],
#  [('具体游戏体验', '正')],
#  [('', '')],
#  [('味道', '正')],
#  [('', '')],
#  [('推荐亲子入住', '正')],
#  [('', '')],
#  [('', '')],
#  [('文化主题', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '正')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('面积', '正')],
#  [('儿童活动', '负')],
#  [('儿童日用品', '其他')],
#  [('', '')],
#  [('儿童娱乐区', '正')],
#  [('', '')],
#  [('网速', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '其他')],
#  [('', '')],
#  [('显卡', '正')],
#  [('面积', '负')],
#  [('', '')],
#  [('显卡', '正')],
#  [('', '')],
#  [('儿童餐饮', '正')],
#  [('', '')],
#  [('键盘', '负')],
#  [('网速', '正')],
#  [('笼统电竞体验', '正')],
#  [('网速', '正')],
#  [('鼠标', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童玩具', '其他')],
#  [('', '')],
#  [('面积', '正')],
#  [('文化主题', '其他')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('键盘', '负')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '其他')],
#  [('显卡', '正')],
#  [('', '')],
#  [('', '')],
#  [('显示器', '负')],
#  [('键盘', '正')],
#  [('', '')],
#  [('', '')],
#  [('键盘', '负')],
#  [('动物', '其他')],
#  [('', '')],
#  [('网速', '正')],
#  [('鼠标', '正')],
#  [('', '')],
#  [('', '')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('鼠标', '负')],
#  [('鼠标', '正')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('儿童活动', '其他')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('面积', '正')],
#  [('儿童餐饮', '其他')],
#  [('', '')],
#  [('键盘', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('面积', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('键盘', '负')],
#  [('', '')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('儿童餐饮', '其他')],
#  [('显卡', '正')],
#  [('孩子体验感受', '正')],
#  [('电竞椅', '正')],
#  [('文化主题', '正')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('显示器', '负')],
#  [('', '')],
#  [('面积', '正')],
#  [('儿童活动', '正')],
#  [('', '')],
#  [('鼠标', '负')],
#  [('面积', '正')],
#  [('显卡', '正')],
#  [('儿童玩具', '正')],
#  [('键盘', '负')],
#  [('儿童活动', '其他')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('味道', '正')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('儿童娱乐区', '其他')],
#  [('电竞椅', '正')],
#  [('儿童娱乐区', '其他')],
#  [('', '')],
#  [('面积', '负')],
#  [('网速', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童餐饮', '负')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('显卡', '正')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('', '')],
#  [('电竞椅', '负')],
#  [('', '')],
#  [('', '')],
#  [('味道', '正')],
#  [('显示器', '正')],
#  [('显卡', '正')],
#  [('儿童日用品', '其他')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('儿童餐饮', '正')],
#  [('鼠标', '正')],
#  [('键盘', '正')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童玩具', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('', '')],
#  [('面积', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('键盘', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '其他')],
#  [('儿童日用品', '其他')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童活动', '其他')],
#  [('', '')],
#  [('儿童餐饮', '正')],
#  [('', '')],
#  [('鼠标', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('面积', '正')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('显示器', '正')],
#  [('儿童玩具', '正')],
#  [('儿童娱乐区', '其他')],
#  [('', '')],
#  [('餐食', '负')],
#  [('显卡', '负')],
#  [('餐食', '负')],
#  [('文化主题', '正')],
#  [('', '')],
#  [('网速', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('文化主题', '其他')],
#  [('', '')],
#  [('推荐亲子入住', '正')],
#  [('', '')],
#  [('文化主题', '其他')],
#  [('', '')],
#  [('电竞椅', '正')],
#  [('电竞椅', '正')],
#  [('儿童娱乐区', '其他')],
#  [('耳机', '正')],
#  [('', '')],
#  [('', '')],
#  [('电竞椅', '其他')],
#  [('', '')],
#  [('电竞椅', '正')],
#  [('', '')],
#  [('显卡', '正')],
#  [('', '')],
#  [('儿童娱乐区', '负')],
#  [('', '')],
#  [('显卡', '正')],
#  [('儿童餐饮', '正')],
#  [('孩子体验感受', '正')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('', '')],
#  [('电竞椅', '负')],
#  [('笼统游戏体验', '正')],
#  [('儿童娱乐区', '正')],
#  [('笼统游戏体验', '正')],
#  [('餐食', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('鼠标', '负')],
#  [('', '')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('味道', '正')],
#  [('餐食', '正')],
#  [('', '')],
#  [('儿童娱乐区', '其他')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('面积', '正')],
#  [('内存', '其他')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童餐饮', '其他')],
#  [('', '')],
#  [('', '')],
#  [('电竞椅', '其他')],
#  [('电竞椅', '正')],
#  [('儿童餐饮', '负')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('面积', '正')],
#  [('', '')],
#  [('', '')],
#  [('面积', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童日用品', '负')],
#  [('', '')],
#  [('推荐电竞入住', '正')],
#  [('显卡', '正')],
#  [('', '')],
#  [('儿童玩具', '其他')],
#  [('', '')],
#  [('儿童活动', '正')],
#  [('', '')],
#  [('面积', '正')],
#  [('键盘', '负')],
#  [('', '')],
#  [('', '')],
#  [('儿童餐饮', '负')],
#  [('', '')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('', '')],
#  [('儿童日用品', '其他')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('具体游戏体验', '正')],
#  [('', '')],
#  [('笼统电竞体验', '正')],
#  [('', '')],
#  [('推荐亲子入住', '负')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('儿童餐饮', '负')],
#  [('自然景观', '正')],
#  [('味道', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '负')],
#  [('显示器', '其他')],
#  [('文化主题', '正')],
#  [('', '')],
#  [('', '')],
#  [('面积', '正')],
#  [('', '')],
#  [('', '')],
#  [('耳机', '负')],
#  [('鼠标', '正')],
#  [('', '')],
#  [('餐食', '正')],
#  [('鼠标', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('味道', '正')],
#  [('网速', '正')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('儿童日用品', '其他')],
#  [('显卡', '正')],
#  [('儿童娱乐区', '其他')],
#  [('文化主题', '其他')],
#  [('面积', '负')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('电竞椅', '其他')],
#  [('', '')],
#  [('推荐亲子入住', '负')],
#  [('儿童玩具', '正')],
#  [('孩子体验感受', '正')],
#  [('耳机', '正')],
#  [('', '')],
#  [('文化主题', '其他')],
#  [('', '')],
#  [('', '')],
#  [('网速', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('儿童娱乐区', '其他')],
#  [('味道', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童玩具', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童礼品', '其他')],
#  [('', '')],
#  [('儿童玩具', '其他')],
#  [('', '')],
#  [('', '')],
#  [('面积', '负')],
#  [('网速', '正')],
#  [('孩子体验感受', '正')],
#  [('推荐电竞入住', '负')],
#  [('键盘', '负')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('', '')],
#  [('文化主题', '正')],
#  [('', '')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('儿童玩具', '其他')],
#  [('儿童日用品', '正')],
#  [('', '')],
#  [('儿童礼品', '负')],
#  [('耳机', '负')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '正')],
#  [('网速', '正')],
#  [('推荐电竞入住', '正')],
#  [('自然景观', '正')],
#  [('儿童娱乐区', '负')],
#  [('', '')],
#  [('', '')],
#  [('文化主题', '正')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童日用品', '其他')],
#  [('笼统游戏体验', '正')],
#  [('网速', '正')],
#  [('推荐电竞入住', '正')],
#  [('面积', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('耳机', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('味道', '负')],
#  [('儿童日用品', '其他')],
#  [('', '')],
#  [('儿童玩具', '其他')],
#  [('电竞椅', '正')],
#  [('儿童日用品', '其他')],
#  [('鼠标', '负')],
#  [('儿童玩具', '正')],
#  [('', '')],
#  [('面积', '正')],
#  [('', '')],
#  [('', '')],
#  [('鼠标', '负')],
#  [('孩子体验感受', '负')],
#  [('', '')],
#  [('电竞椅', '负')],
#  [('', '')],
#  [('', '')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('推荐亲子入住', '正')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('cpu', '正')],
#  [('', '')],
#  [('儿童玩具', '其他')],
#  [('', '')],
#  [('儿童礼品', '正')],
#  [('', '')],
#  [('', '')],
#  [('餐食', '负')],
#  [('', '')],
#  [('', '')],
#  [('推荐亲子入住', '负')],
#  [('儿童餐饮', '其他')],
#  [('文化主题', '负')],
#  [('网速', '正')],
#  [('具体游戏体验', '正')],
#  [('显示器', '正')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('网速', '正')],
#  [('', '')],
#  [('网速', '正')],
#  [('文化主题', '正')],
#  [('', '')],
#  [('网速', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('笼统游戏体验', '其他')],
#  [('', '')],
#  [('', '')],
#  [('儿童餐饮', '负')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('儿童日用品', '其他')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('儿童玩具', '其他')],
#  [('笼统游戏体验', '正')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('显卡', '正')],
#  [('餐食', '负')],
#  [('儿童餐饮', '负')],
#  [('电竞椅', '正')],
#  [('', '')],
#  [('显卡', '正')],
#  [('鼠标', '正')],
#  [('', '')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('儿童日用品', '负')],
#  [('味道', '正')],
#  [('儿童玩具', '其他')],
#  [('', '')],
#  [('味道', '正')],
#  [('儿童娱乐区', '其他')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童日用品', '其他')],
#  [('儿童餐饮', '正')],
#  [('网速', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('笼统电竞体验', '正')],
#  [('', '')],
#  [('网速', '正')],
#  [('', '')],
#  [('电竞椅', '负')],
#  [('', '')],
#  [('', '')],
#  [('推荐亲子入住', '负')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童娱乐区', '正')],
#  [('具体游戏体验', '正')],
#  [('', '')],
#  [('网速', '负')],
#  [('', '')],
#  [('面积', '正')],
#  [('鼠标', '正')],
#  [('具体游戏体验', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童餐饮', '正')],
#  [('儿童餐饮', '负')],
#  [('', '')],
#  [('儿童娱乐区', '负')],
#  [('', '')],
#  [('', '')],
#  [('儿童活动', '其他')],
#  [('推荐电竞入住', '正')],
#  [('鼠标', '正')],
#  [('鼠标', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童餐饮', '正')],
#  [('儿童玩具', '其他')],
#  [('儿童日用品', '其他')],
#  [('推荐亲子入住', '负')],
#  [('', '')],
#  [('', '')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('儿童娱乐区', '负')],
#  [('', '')],
#  [('味道', '正')],
#  [('', '')],
#  [('', '')],
#  [('笼统游戏体验', '负')],
#  [('儿童餐饮', '负')],
#  [('', '')],
#  [('', '')],
#  [('味道', '正')],
#  [('儿童玩具', '其他')],
#  [('鼠标', '正')],
#  [('儿童娱乐区', '正')],
#  [('', '')],
#  [('', '')],
#  [('面积', '正')],
#  [('推荐电竞入住', '正')],
#  [('', '')],
#  [('', '')],
#  [('推荐亲子入住', '负')],
#  [('笼统电竞体验', '正')],
#  [('耳机', '负')],
#  [('笼统游戏体验', '正')],
#  [('孩子体验感受', '正')],
#  [('笼统电竞体验', '正')],
#  [('', '')],
#  [('键盘', '负')],
#  [('笼统游戏体验', '正')],
#  [('', '')],
#  [('味道', '正')],
#  [('', '')],
#  [('儿童玩具', '其他')],
#  [('电竞椅', '其他')],
#  [('', '')],
#  [('鼠标', '正')],
#  [('', '')],
#  [('', '')],
#  [('孩子体验感受', '正')],
#  [('', '')],
#  [('儿童日用品', '正')],
#  [('儿童日用品', '正')],
#  [('', '')],
#  [('自然景观', '正')],
#  [('', '')],
#  [('网速', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('面积', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童活动', '正')],
#  [('儿童餐饮', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('网速', '正')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('电竞椅', '正')],
#  [('', '')],
#  [('', '')],
#  [('网速', '正')],
#  [('电竞椅', '负')],
#  [('', '')],
#  [('', '')],
#  [('餐食', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童餐饮', '正')],
#  [('', '')],
#  [('', '')],
#  [('儿童日用品', '其他')],
#  [('', '')],
#  [('', '')],
#  [('', '')],
#  [('儿童餐饮', '其他')],
#  [('', '')],
#  [('电竞椅', '正')],
#  [('', '')],
#  [('', '')],
#  ...]

# %%
def compute_f1_scores_cate(pred_pt, gold_pt):
    """
    Function to compute F1 scores with pred and gold pairs/triplets
    The input needs to be already processed
    """
    # number of true postive, gold standard, predicted aspect terms
    n_tp, n_gold, n_pred = 0, 0, 0
    cls_tp={}
    cls_n_pred={}
    cls_n_gold={}
    res={}
    for i in range(len(pred_pt)):
        gold_pt[i]=list(set(gold_pt[i]))
        pred_pt[i]=list(set(pred_pt[i]))
        n_gold += len(gold_pt[i])
        n_pred += len(pred_pt[i])
        # print(type(gold_pt[i]))
        # print(type(pred_pt[i]))
        for j in gold_pt[i]:
            if j[0] not in cls_n_gold.keys():
                cls_n_gold[j[0]]=1
            else:
                cls_n_gold[j[0]]+=1
        for j in pred_pt[i]:
            if j[0] not in cls_n_pred.keys():
                cls_n_pred[j[0]]=1
            else:
                cls_n_pred[j[0]]+=1
            if j in gold_pt[i]:
                n_tp += 1
                if j[0] not in cls_tp.keys():
                    cls_tp[j[0]]=1
                else:
                    cls_tp[j[0]]+=1
    for k in cls_tp.keys():
        p= float(cls_tp[k]) / float(cls_n_pred[k]) if cls_n_pred[k] != 0 else 0
        r = float(cls_tp[k]) / float(cls_n_gold[k]) if cls_n_gold[k] != 0 else 0
        f1=2 * p * r/ (p + r) if p != 0 or r != 0 else 0
        res[k]={'precision': p, 'recall': r, 'f1': f1}
    precision = float(n_tp) / float(n_pred) if n_pred != 0 else 0
    recall = float(n_tp) / float(n_gold) if n_gold != 0 else 0
    f1 = 2 * precision * recall / (precision + recall) if precision != 0 or recall != 0 else 0
    scores = {'precision': precision, 'recall': recall, 'f1': f1}

    return scores,res
def compute_f1_scores(pred_pt, gold_pt):
    """
    Function to compute F1 scores with pred and gold pairs/triplets
    The input needs to be already processed
    """
    # number of true postive, gold standard, predicted aspect terms
    n_tp, n_gold, n_pred = 0, 0, 0

    for i in range(len(pred_pt)):
        gold_pt[i]=list(set(gold_pt[i]))
        pred_pt[i]=list(set(pred_pt[i]))
        n_gold += len(gold_pt[i])
        n_pred += len(pred_pt[i])
        # if len(gold_pt[i])==0:
        #     n_tp+=1
        #     n_gold +=1
        # if len(pred_pt[i])==0:
        #     n_pred +=1
        # if len(gold_pt[i])==0 and len(pred_pt[i])==0:
        #     n_tp+=1
        for t in pred_pt[i]:
            if t in gold_pt[i]:
                n_tp += 1

    precision = float(n_tp) / float(n_pred) if n_pred != 0 else 0
    recall = float(n_tp) / float(n_gold) if n_gold != 0 else 0
    f1 = 2 * precision * recall / (precision + recall) if precision != 0 or recall != 0 else 0
    scores = {'precision': precision, 'recall': recall, 'f1': f1}

    return scores

# %%
raw_scores = compute_f1_scores(pred, lab)
raw_scores
# Out:
# 1
# {'precision': 0.8878125703987385,
#  'recall': 0.8589799476896252,
#  'f1': 0.8731583028691703}

# %%
raw_scores = compute_f1_scores_cate(pred, lab)
raw_scores
# Out:
# ({'precision': 0.8878125703987385,
#   'recall': 0.8589799476896252,
#   'f1': 0.8731583028691703},
#  {'网速': {'precision': 0.9444444444444444,
#    'recall': 0.9834710743801653,
#    'f1': 0.9635627530364373},
#   '笼统电竞体验': {'precision': 0.7916666666666666,
#    'recall': 0.7702702702702703,
#    'f1': 0.7808219178082192},
#   '儿童娱乐区': {'precision': 0.8228571428571428,
#    'recall': 0.8470588235294118,
#    'f1': 0.8347826086956521},
#   '推荐亲子入住': {'precision': 0.9457831325301205,
#    'recall': 0.9457831325301205,
#    'f1': 0.9457831325301205},
#   '儿童玩具': {'precision': 0.8992248062015504,
#    'recall': 0.8787878787878788,
#    'f1': 0.888888888888889},
#   '': {'precision': 0.9211237169097785,
#    'recall': 0.9291553133514986,
#    'f1': 0.9251220835594139},
#   '儿童餐饮': {'precision': 0.8359375,
#    'recall': 0.8699186991869918,
#    'f1': 0.852589641434263},
#   '孩子体验感受': {'precision': 0.9035532994923858,
#    'recall': 0.9468085106382979,
#    'f1': 0.9246753246753245},
#   '键盘': {'precision': 0.900990099009901,
#    'recall': 0.8504672897196262,
#    'f1': 0.875},
#   '周边': {'precision': 0.7761194029850746,
#    'recall': 0.6046511627906976,
#    'f1': 0.6797385620915033},
#   '自然景观': {'precision': 0.7906976744186046,
#    'recall': 0.7010309278350515,
#    'f1': 0.7431693989071039},
#   '耳机': {'precision': 0.8688524590163934,
#    'recall': 0.8688524590163934,
#    'f1': 0.8688524590163934},
#   '鼠标': {'precision': 0.8837209302325582,
#    'recall': 0.7916666666666666,
#    'f1': 0.8351648351648352},
#   '儿童活动': {'precision': 0.8, 'recall': 0.8253968253968254, 'f1': 0.8125},
#   '儿童礼品': {'precision': 0.6666666666666666,
#    'recall': 0.72,
#    'f1': 0.6923076923076923},
#   '笼统游戏体验': {'precision': 0.9193548387096774,
#    'recall': 0.8702290076335878,
#    'f1': 0.8941176470588236},
#   '儿童日用品': {'precision': 0.8571428571428571,
#    'recall': 0.782608695652174,
#    'f1': 0.8181818181818182},
#   '电竞椅': {'precision': 0.9069767441860465,
#    'recall': 0.8125,
#    'f1': 0.8571428571428572},
#   '餐食': {'precision': 0.8524590163934426,
#    'recall': 0.6666666666666666,
#    'f1': 0.7482014388489209},
#   '显示器': {'precision': 0.8095238095238095,
#    'recall': 0.68,
#    'f1': 0.7391304347826089},
#   '面积': {'precision': 0.9245283018867925,
#    'recall': 0.8099173553719008,
#    'f1': 0.8634361233480177},
#   '味道': {'precision': 0.7398373983739838,
#    'recall': 0.7398373983739838,
#    'f1': 0.7398373983739838},
#   '具体游戏体验': {'precision': 0.8297872340425532,
#    'recall': 0.8666666666666667,
#    'f1': 0.8478260869565217},
#   '推荐电竞入住': {'precision': 0.8870967741935484,
#    'recall': 0.7971014492753623,
#    'f1': 0.8396946564885496},
#   '显卡': {'precision': 0.94,
#    'recall': 0.6911764705882353,
#    'f1': 0.7966101694915254},
#   '文化主题': {'precision': 0.7590361445783133,
#    'recall': 0.7411764705882353,
#    'f1': 0.7499999999999999},
#   '内存': {'precision': 0.9411764705882353,
#    'recall': 0.8421052631578947,
#    'f1': 0.8888888888888888},
#   '动物': {'precision': 1.0, 'recall': 0.5, 'f1': 0.6666666666666666},
#   'cpu': {'precision': 0.7647058823529411,
#    'recall': 0.52,
#    'f1': 0.6190476190476191}})

# %%
labs=[]
for i in range(len(lab)):
    for j in range(len(lab[i])):
        if lab[i][j][0] not in labs:
            if lab[i][j][0]=='':
                print(lab[i])
                print(pre[i])
            labs.append(lab[i][j][0])
print(labs)
# Out:
# [('', '')]
# [['文化主题' '正']]
# ['网速', '笼统电竞体验', '显卡', '儿童娱乐区', '推荐亲子入住', '周边', '儿童玩具', '', '儿童餐饮', '孩子体验感受', '键盘', '自然景观', '耳机', '鼠标', '儿童活动', '儿童礼品', '显示器', '笼统游戏体验', '儿童日用品', '电竞椅', '餐食', '面积', '文化主题', '味道', '具体游戏体验', '推荐电竞入住', '内存', 'cpu', '动物']

# %%
def compute_f1_scores_2(pred_pt, gold_pt, labs):
    """
    Function to compute F1 scores with pred and gold pairs/triplets
    The input needs to be already processed
    """
    # number of true postive, gold standard, predicted aspect terms
    n_tp, n_gold, n_pred = 0, 0, 0

    for i in range(len(pred_pt)):
        gold_pt[i]=list(set(gold_pt[i]))
        pred_pt[i]=list(set(pred_pt[i]))
        n_gold += 30
        n_pred += 30
        for t in pred_pt[i]:
            if t in gold_pt[i]:
                n_tp += 1

    precision = float(n_tp) / float(n_pred) if n_pred != 0 else 0
    recall = float(n_tp) / float(n_gold) if n_gold != 0 else 0
    f1 = 2 * precision * recall / (precision + recall) if precision != 0 or recall != 0 else 0
    scores = {'precision': precision, 'recall': recall, 'f1': f1}

    return scores

# %%
def compute_f1_scores(pred_pt, gold_pt):
    """
    Function to compute F1 scores with pred and gold pairs/triplets
    The input needs to be already processed
    """
    # number of true postive, gold standard, predicted aspect terms
    n_tp, n_gold, n_pred = 0, 0, 0

    for i in range(len(pred_pt)):
        gold_pt[i]=list(set(gold_pt[i]))
        pred_pt[i]=list(set(pred_pt[i]))
        n_gold += len(gold_pt[i])
        n_pred += len(pred_pt[i])
        if len(gold_pt[i])==0:
            n_tp+=1
            n_gold +=1
        if len(pred_pt[i])==0:
            n_pred +=1
        if len(gold_pt[i])==0 and len(pred_pt[i])==0:
            n_tp+=1
        for t in pred_pt[i]:
            if t in gold_pt[i]:
                n_tp += 1

    precision = float(n_tp) / float(n_pred) if n_pred != 0 else 0
    recall = float(n_tp) / float(n_gold) if n_gold != 0 else 0
    f1 = 2 * precision * recall / (precision + recall) if precision != 0 or recall != 0 else 0
    scores = {'precision': precision, 'recall': recall, 'f1': f1}

    return scores
